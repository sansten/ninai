# %% [markdown]
# # Chapter 6 Workbook: Ninai for LLMOps and MLOps
#
# Hands-on workbook for the LLMOps and MLOps chapter. The examples show how Ninai behaves as an operational system with retrieval, review, evaluation, and observable outputs.

# %% [markdown]
# ## How To Use This Workbook
#
# Read the matching subsection in the book, then open the corresponding heading here. The code cells include expected output so the learning goal is visible even before you run anything.

# %% [markdown]
# ## Section Map
# - `6.2 LLMOps and MLOps Responsibilities in Agentic Platforms`
# - `6.3 Production Contracts: Prompts, Models, and Tool Interfaces`
# - `6.4 Runtime Orchestration and Model Routing Patterns`
# - `6.5 Planning for Reliability, Cost, and Latency`
# - `6.6 Context Quality and Retrieval Operations`
# - `6.7 Guardrails, Verification, and Runtime Policy`
# - `6.8 Fallback Strategy and Degraded Runtime Modes`
# - `6.9 Memory Operations and Stateful Coordination`
# - `6.10 SLOs: Latency, Throughput, and Cost Tradeoffs`
# - `6.11 Failure Modes in LLMOps Pipelines`
# - `6.12 Human Review and Escalation Operations`
# - `6.13 Testing, Eval Suites, and Release Gates`
# - `6.14 Observability: What to Measure Continuously`
# - `6.15 When to Introduce New Runtime Components`
# - `6.16 When to Consolidate Pipelines and Services`
# - `6.17 Delivery Workflow for LLMOps Teams`
# - `6.18 End-to-End Production Runbook Walkthrough`
# - `6.18a Deep Dive: Handling Model Drift in Production`
# - `6.18b Existing Operational Challenges`
# - `6.18c Cognitive Systems Architecture in Ninai`
# - `6.18d Challenge-to-Pattern Mapping`
# - `6.18e Designing for Cognitive Stability`
# - `6.18f Operating Model: From Blueprint to Production`
# - `6.18g Model Drift Detection and Response Playbook`
# - `6.18h Evaluation Gates and Safe Rollout Strategy`
# - `6.18i Rollback Orchestration and Cost Governance`
# - `6.19 Postmortem: Drift and Regression Under Load`
# - `6.20 Chapter Lab`
# - `6.21 Conclusion`

# %% [markdown]
# ## 6.2 LLMOps and MLOps Responsibilities in Agentic Platforms
#
# Notebook anchor: `62-llmops-and-mlops-responsibilities-in-agentic-platforms`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
roles = ['platform', 'mlops', 'review']
for role in roles:
    print(role, 'owns a distinct runtime responsibility')
# Out:
# platform owns a distinct runtime responsibility
# mlops owns a distinct runtime responsibility
# review owns a distinct runtime responsibility

# %% [markdown]
# ## 6.3 Production Contracts: Prompts, Models, and Tool Interfaces
#
# Notebook anchor: `63-production-contracts-prompts-models-and-tool-interfaces`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.4 Runtime Orchestration and Model Routing Patterns
#
# Notebook anchor: `64-runtime-orchestration-and-model-routing-patterns`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.5 Planning for Reliability, Cost, and Latency
#
# Notebook anchor: `65-planning-for-reliability-cost-and-latency`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.6 Context Quality and Retrieval Operations
#
# Notebook anchor: `66-context-quality-and-retrieval-operations`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
results = client.memories.search(
    query='incident rollback procedure',
    tags=['ops'],
    limit=3,
    hybrid=True,
)
for item in results.items:
    print(item.id, item.score)
# Out:
# mem_201 0.91
# mem_188 0.86
# mem_177 0.79

# %% [markdown]
# ## 6.7 Guardrails, Verification, and Runtime Policy
#
# Notebook anchor: `67-guardrails-verification-and-runtime-policy`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.8 Fallback Strategy and Degraded Runtime Modes
#
# Notebook anchor: `68-fallback-strategy-and-degraded-runtime-modes`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.9 Memory Operations and Stateful Coordination
#
# Notebook anchor: `69-memory-operations-and-stateful-coordination`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.10 SLOs: Latency, Throughput, and Cost Tradeoffs
#
# Notebook anchor: `610-slos-latency-throughput-and-cost-tradeoffs`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.11 Failure Modes in LLMOps Pipelines
#
# Notebook anchor: `611-failure-modes-in-llmops-pipelines`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.12 Human Review and Escalation Operations
#
# Notebook anchor: `612-human-review-and-escalation-operations`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
print('queue depth:', 2)
print('top item:', 'mem_244 review_recommended')
# Out:
# queue depth: 2
# top item: mem_244 review_recommended

# %% [markdown]
# ## 6.13 Testing, Eval Suites, and Release Gates
#
# Notebook anchor: `613-testing-eval-suites-and-release-gates`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
gate = {'task_success_min': 0.86, 'policy_violation_max': 0.01}
actual = {'task_success': 0.90, 'policy_violation': 0.00}
print(actual['task_success'] >= gate['task_success_min'])
print(actual['policy_violation'] <= gate['policy_violation_max'])
# Out:
# True
# True

# %% [markdown]
# ## 6.14 Observability: What to Measure Continuously
#
# Notebook anchor: `614-observability-what-to-measure-continuously`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.15 When to Introduce New Runtime Components
#
# Notebook anchor: `615-when-to-introduce-new-runtime-components`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.16 When to Consolidate Pipelines and Services
#
# Notebook anchor: `616-when-to-consolidate-pipelines-and-services`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.17 Delivery Workflow for LLMOps Teams
#
# Notebook anchor: `617-delivery-workflow-for-llmops-teams`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18 End-to-End Production Runbook Walkthrough
#
# Notebook anchor: `618-end-to-end-production-runbook-walkthrough`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
runbook = client.memories.create(
    title='Rollback checklist',
    content='Shift traffic to stable bundle and verify health.',
    scope='organization',
    tags=['ops', 'rollback'],
)
print(runbook.id, runbook.scope)
# Out:
# mem_310 organization

# %% [markdown]
# ## 6.18a Deep Dive: Handling Model Drift in Production
#
# Notebook anchor: `618a-deep-dive-handling-model-drift-in-production`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18b Existing Operational Challenges
#
# Notebook anchor: `618b-existing-operational-challenges`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18c Cognitive Systems Architecture in Ninai
#
# Notebook anchor: `618c-cognitive-systems-architecture-in-ninai`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18d Challenge-to-Pattern Mapping
#
# Notebook anchor: `618d-challenge-to-pattern-mapping`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18e Designing for Cognitive Stability
#
# Notebook anchor: `618e-designing-for-cognitive-stability`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18f Operating Model: From Blueprint to Production
#
# Notebook anchor: `618f-operating-model-from-blueprint-to-production`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18g Model Drift Detection and Response Playbook
#
# Notebook anchor: `618g-model-drift-detection-and-response-playbook`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18h Evaluation Gates and Safe Rollout Strategy
#
# Notebook anchor: `618h-evaluation-gates-and-safe-rollout-strategy`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.18i Rollback Orchestration and Cost Governance
#
# Notebook anchor: `618i-rollback-orchestration-and-cost-governance`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.19 Postmortem: Drift and Regression Under Load
#
# Notebook anchor: `619-postmortem-drift-and-regression-under-load`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.20 Chapter Lab
#
# Notebook anchor: `620-chapter-lab`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 6.21 Conclusion
#
# Notebook anchor: `621-conclusion`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.
