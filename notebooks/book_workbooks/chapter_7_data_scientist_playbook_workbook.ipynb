# %% [markdown]
# # Chapter 7 Workbook: Data Scientist Playbook
#
# Hands-on workbook for the data scientist chapter. The examples emphasize reproducibility, retrieval evidence, calibration, and clear experiment outputs linked back to Ninai data structures.

# %% [markdown]
# ## How To Use This Workbook
#
# Read the matching subsection in the book, then open the corresponding heading here. The code cells include expected output so the learning goal is visible even before you run anything.

# %% [markdown]
# ## Section Map
# - `7.2 Experimental Design for Agentic Intelligence`
# - `7.3 Dataset and Feature Contracts for Cognitive Workflows`
# - `7.4 Causal Hypothesis Pipelines and Orchestration`
# - `7.5 Planning Experiments for Reliability and Validity`
# - `7.6 Context Quality as a Scientific Variable`
# - `7.7 Verification, Calibration, and Research Guardrails`
# - `7.8 Robustness Under Distribution Shift`
# - `7.9 Memory as Longitudinal Experimental State`
# - `7.10 Accuracy, Calibration, and Cost Tradeoffs`
# - `7.11 Failure Modes in AGI-Oriented Data Science`
# - `7.12 Human Review in Scientific Loops`
# - `7.13 Evaluation Suites and Reproducibility Gates`
# - `7.14 Observability for Learning Systems`
# - `7.15 When to Add New Scientific Components`
# - `7.16 When to Simplify Experimental Pipelines`
# - `7.17 Delivery Workflow for Data Science Teams`
# - `7.18 End-to-End Scientific Workflow Walkthrough`
# - `7.18a Deep Dive: Causal Inference in Customer Retention`
# - `7.18b Existing Scientific Challenges`
# - `7.18c Scientific Evidence Model in Ninai`
# - `7.18d Challenge-to-Pattern Mapping`
# - `7.18e Designing for Cognitive Stability`
# - `7.18f Operating Model: From Blueprint to Production`
# - `7.18g Drift Detection and Causal Validation Playbook`
# - `7.18h Evaluation Gates and Reproducible Rollout Strategy`
# - `7.18i Experiment Rollback and Research Cost Governance`
# - `7.19 Postmortem: Causal Misattribution Under Drift`
# - `7.20 Chapter Lab`
# - `7.21 Conclusion`

# %% [markdown]
# ## 7.2 Experimental Design for Agentic Intelligence
#
# Notebook anchor: `72-experimental-design-for-agentic-intelligence`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
hypotheses = ['better tags improve recall', 'hybrid search improves exact phrase retrieval']
for h in hypotheses:
    print('-', h)
# Out:
# - better tags improve recall
# - hybrid search improves exact phrase retrieval

# %% [markdown]
# ## 7.3 Dataset and Feature Contracts for Cognitive Workflows
#
# Notebook anchor: `73-dataset-and-feature-contracts-for-cognitive-workflows`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.4 Causal Hypothesis Pipelines and Orchestration
#
# Notebook anchor: `74-causal-hypothesis-pipelines-and-orchestration`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.5 Planning Experiments for Reliability and Validity
#
# Notebook anchor: `75-planning-experiments-for-reliability-and-validity`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.6 Context Quality as a Scientific Variable
#
# Notebook anchor: `76-context-quality-as-a-scientific-variable`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
results = client.memories.search(
    query='retention risk after price increase',
    tags=['retention'],
    limit=3,
    hybrid=True,
)
for item in results.items:
    print(item.id, item.score, item.content_preview)
# Out:
# mem_401 0.93 retention complaints spiked after the new plan
# mem_399 0.84 price increase support ticket summary
# mem_388 0.77 churn discussion from weekly review

# %% [markdown]
# ## 7.7 Verification, Calibration, and Research Guardrails
#
# Notebook anchor: `77-verification-calibration-and-research-guardrails`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
expected = 0.80
observed = 0.78
print('calibration gap:', round(expected - observed, 2))
# Out:
# calibration gap: 0.02

# %% [markdown]
# ## 7.8 Robustness Under Distribution Shift
#
# Notebook anchor: `78-robustness-under-distribution-shift`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.9 Memory as Longitudinal Experimental State
#
# Notebook anchor: `79-memory-as-longitudinal-experimental-state`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.10 Accuracy, Calibration, and Cost Tradeoffs
#
# Notebook anchor: `710-accuracy-calibration-and-cost-tradeoffs`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.11 Failure Modes in AGI-Oriented Data Science
#
# Notebook anchor: `711-failure-modes-in-agi-oriented-data-science`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.12 Human Review in Scientific Loops
#
# Notebook anchor: `712-human-review-in-scientific-loops`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.13 Evaluation Suites and Reproducibility Gates
#
# Notebook anchor: `713-evaluation-suites-and-reproducibility-gates`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
print('eval run:', 'eval_120')
print('status:', 'passed reproducibility gate')
# Out:
# eval run: eval_120
# status: passed reproducibility gate

# %% [markdown]
# ## 7.14 Observability for Learning Systems
#
# Notebook anchor: `714-observability-for-learning-systems`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.15 When to Add New Scientific Components
#
# Notebook anchor: `715-when-to-add-new-scientific-components`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.16 When to Simplify Experimental Pipelines
#
# Notebook anchor: `716-when-to-simplify-experimental-pipelines`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.17 Delivery Workflow for Data Science Teams
#
# Notebook anchor: `717-delivery-workflow-for-data-science-teams`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18 End-to-End Scientific Workflow Walkthrough
#
# Notebook anchor: `718-end-to-end-scientific-workflow-walkthrough`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
memory = client.memories.create(
    title='Retention experiment note',
    content='Users citing price increase showed elevated churn risk.',
    scope='organization',
    tags=['retention', 'experiment'],
)
print(memory.id, memory.tags)
# Out:
# mem_455 ['retention', 'experiment']

# %% [markdown]
# ## 7.18a Deep Dive: Causal Inference in Customer Retention
#
# Notebook anchor: `718a-deep-dive-causal-inference-in-customer-retention`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18b Existing Scientific Challenges
#
# Notebook anchor: `718b-existing-scientific-challenges`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18c Scientific Evidence Model in Ninai
#
# Notebook anchor: `718c-scientific-evidence-model-in-ninai`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18d Challenge-to-Pattern Mapping
#
# Notebook anchor: `718d-challenge-to-pattern-mapping`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18e Designing for Cognitive Stability
#
# Notebook anchor: `718e-designing-for-cognitive-stability`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18f Operating Model: From Blueprint to Production
#
# Notebook anchor: `718f-operating-model-from-blueprint-to-production`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18g Drift Detection and Causal Validation Playbook
#
# Notebook anchor: `718g-drift-detection-and-causal-validation-playbook`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18h Evaluation Gates and Reproducible Rollout Strategy
#
# Notebook anchor: `718h-evaluation-gates-and-reproducible-rollout-strategy`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.18i Experiment Rollback and Research Cost Governance
#
# Notebook anchor: `718i-experiment-rollback-and-research-cost-governance`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.19 Postmortem: Causal Misattribution Under Drift
#
# Notebook anchor: `719-postmortem-causal-misattribution-under-drift`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.20 Chapter Lab
#
# Notebook anchor: `720-chapter-lab`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 7.21 Conclusion
#
# Notebook anchor: `721-conclusion`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.
