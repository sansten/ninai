# %% [markdown]
# # Chapter 8 Workbook: Getting Started as a Junior Developer
#
# Hands-on workbook for the junior developer chapter. The examples are deliberately concrete: start the stack, create a memory, search it back, inspect fields, and fix a scope bug with visible output.

# %% [markdown]
# ## How To Use This Workbook
#
# Read the matching subsection in the book, then open the corresponding heading here. The code cells include expected output so the learning goal is visible even before you run anything.

# %% [markdown]
# ## Section Map
# - `8.2 First Principles: How to Think About Ninai`
# - `8.3 Environment Setup and Local Stack`
# - `8.4 Understanding the First Request Lifecycle`
# - `8.5 Writing Your First Memory`
# - `8.6 Searching Memories Like a Real Ninai Developer`
# - `8.7 Scope, Security, and RLS Basics`
# - `8.8 Common Beginner Failure Modes`
# - `8.9 Reading and Writing Memory Correctly`
# - `8.10 Performance, Cost, and Reliability Tradeoffs`
# - `8.11 Debugging Agentic Workflows`
# - `8.12 Working with Human-in-the-Loop Flows`
# - `8.13 Testing Strategy for Junior Developers`
# - `8.14 Observability and Logs You Must Read`
# - `8.15 When to Add New Components`
# - `8.16 When to Keep Things Simple`
# - `8.17 Daily Developer Workflow`
# - `8.18 End-to-End Beginner Walkthrough`
# - `8.18a Deep Dive: First Production Bug and Fix`
# - `8.18b Existing Junior Developer Challenges`
# - `8.18c Cognitive Systems Architecture in Ninai`
# - `8.18d Challenge-to-Pattern Mapping`
# - `8.19 Postmortem: Beginner Mistake Under Pressure`
# - `8.20 Chapter Lab`
# - `8.21 Conclusion`

# %% [markdown]
# ## 8.2 First Principles: How to Think About Ninai
#
# Notebook anchor: `82-first-principles-how-to-think-about-ninai`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.3 Environment Setup and Local Stack
#
# Notebook anchor: `83-environment-setup-and-local-stack`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
commands = ['docker compose up -d --build', 'curl http://localhost:8000/health']
for command in commands:
    print(command)
# Out:
# docker compose up -d --build
# curl http://localhost:8000/health

# %% [markdown]
# ## 8.4 Understanding the First Request Lifecycle
#
# Notebook anchor: `84-understanding-the-first-request-lifecycle`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.5 Writing Your First Memory
#
# Notebook anchor: `85-writing-your-first-memory`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
memory = client.memories.create(
    title='Fiber outage after plan upgrade',
    content='Customer reported intermittent fiber outage after plan upgrade.',
    scope='organization',
    classification='internal',
    tags=['support', 'fiber'],
)
print(memory.id, memory.scope, memory.classification)
# Out:
# mem_501 organization internal

# %% [markdown]
# ## 8.6 Searching Memories Like a Real Ninai Developer
#
# Notebook anchor: `86-searching-memories-like-a-real-ninai-developer`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
result = client.memories.search(
    query='customer reported intermittent fiber outage after plan upgrade',
    scope='organization',
    tags=['support', 'fiber'],
    limit=3,
    threshold=0.65,
    hybrid=True,
)
for item in result.items:
    print(item.id, item.score, item.content_preview)
# Out:
# mem_501 0.95 Customer reported intermittent fiber outage after plan upgrade.
# mem_488 0.82 Fiber support history for the same customer
# mem_472 0.74 Upgrade-related outage note from prior week

# %% [markdown]
# ## 8.7 Scope, Security, and RLS Basics
#
# Notebook anchor: `87-scope-security-and-rls-basics`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
print('personal search count:', 1)
print('organization search count:', 3)
# Out:
# personal search count: 1
# organization search count: 3

# %% [markdown]
# ## 8.8 Common Beginner Failure Modes
#
# Notebook anchor: `88-common-beginner-failure-modes`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.9 Reading and Writing Memory Correctly
#
# Notebook anchor: `89-reading-and-writing-memory-correctly`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.10 Performance, Cost, and Reliability Tradeoffs
#
# Notebook anchor: `810-performance-cost-and-reliability-tradeoffs`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.11 Debugging Agentic Workflows
#
# Notebook anchor: `811-debugging-agentic-workflows`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.12 Working with Human-in-the-Loop Flows
#
# Notebook anchor: `812-working-with-human-in-the-loop-flows`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
print('queue item:', 'mem_522')
print('reason:', 'review_recommended due to uncertainty')
# Out:
# queue item: mem_522
# reason: review_recommended due to uncertainty

# %% [markdown]
# ## 8.13 Testing Strategy for Junior Developers
#
# Notebook anchor: `813-testing-strategy-for-junior-developers`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.14 Observability and Logs You Must Read
#
# Notebook anchor: `814-observability-and-logs-you-must-read`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.15 When to Add New Components
#
# Notebook anchor: `815-when-to-add-new-components`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.16 When to Keep Things Simple
#
# Notebook anchor: `816-when-to-keep-things-simple`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.17 Daily Developer Workflow
#
# Notebook anchor: `817-daily-developer-workflow`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.18 End-to-End Beginner Walkthrough
#
# Notebook anchor: `818-end-to-end-beginner-walkthrough`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
created = client.memories.create(
    title='Customer outage after upgrade',
    content='Customer reported intermittent fiber outage after plan upgrade.',
    scope='organization',
    classification='internal',
    tags=['support', 'fiber'],
)
results = client.memories.search(
    query='customer reported intermittent fiber outage after plan upgrade',
    scope='organization',
    tags=['support', 'fiber'],
    limit=5,
    threshold=0.65,
    hybrid=True,
)
print(created.id)
print(results.total)
# Out:
# mem_544
# 3

# %% [markdown]
# ## 8.18a Deep Dive: First Production Bug and Fix
#
# Notebook anchor: `818a-deep-dive-first-production-bug-and-fix`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.18b Existing Junior Developer Challenges
#
# Notebook anchor: `818b-existing-junior-developer-challenges`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.18c Cognitive Systems Architecture in Ninai
#
# Notebook anchor: `818c-cognitive-systems-architecture-in-ninai`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.18d Challenge-to-Pattern Mapping
#
# Notebook anchor: `818d-challenge-to-pattern-mapping`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.19 Postmortem: Beginner Mistake Under Pressure
#
# Notebook anchor: `819-postmortem-beginner-mistake-under-pressure`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.20 Chapter Lab
#
# Notebook anchor: `820-chapter-lab`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 8.21 Conclusion
#
# Notebook anchor: `821-conclusion`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.
