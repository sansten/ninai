# %% [markdown]
# # Chapter 5B Workbook: Security and RLS in Ninai
#
# Hands-on workbook for the security chapter. The examples focus on organization isolation, scoped retrieval, review, and evidence that a secure path actually worked.

# %% [markdown]
# ## How To Use This Workbook
#
# Read the matching subsection in the book, then open the corresponding heading here. The code cells include expected output so the learning goal is visible even before you run anything.

# %% [markdown]
# ## Section Map
# - `5B.2 Threat Model for Agentic Workflows`
# - `5B.3 Trust Boundaries and Data Classification`
# - `5B.4 Secure Orchestration Patterns`
# - `5B.5 Security-Aware Planning`
# - `5B.6 Secure Retrieval and Least Privilege`
# - `5B.7 Policy Enforcement and Security Verifiers`
# - `5B.8 Safe Degradation and Incident Modes`
# - `5B.9 RLS as a Core Isolation Layer`
# - `5B.10 Security vs Latency Tradeoffs`
# - `5B.11 Security Failure Modes in Agentic Systems`
# - `5B.12 Human Approval and Access Governance`
# - `5B.13 Security Testing and Red Teaming`
# - `5B.14 Security Observability and Audit Signals`
# - `5B.15 When to Split Security Responsibilities`
# - `5B.16 When to Merge Security Controls`
# - `5B.17 Secure Delivery Workflow`
# - `5B.18 End-to-End Secure Workflow Walkthrough`
# - `5B.18a Deep Dive: Preventing Cross-Tenant Data Leakage`
# - `5B.18b Existing Security Challenges in Agentic Architectures`
# - `5B.18c How Ninai Security Architecture Addresses Them`
# - `5B.18d Security Challenge-to-Control Mapping`
# - `5B.18e Designing for Security Stability`
# - `5B.18f Security Operating Model`
# - `5B.18g RLS Anti-Patterns and How to Avoid Them`
# - `5B.18h Secrets Management and Tool Credential Isolation`
# - `5B.18i Compliance Mapping: From Controls to Evidence`
# - `5B.19 Security Postmortem: RLS Policy Drift`
# - `5B.20 Chapter Lab`
# - `5B.21 Conclusion`

# %% [markdown]
# ## 5B.2 Threat Model for Agentic Workflows
#
# Notebook anchor: `5b2-threat-model-for-agentic-workflows`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.3 Trust Boundaries and Data Classification
#
# Notebook anchor: `5b3-trust-boundaries-and-data-classification`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
classification = ['public', 'internal', 'confidential']
for level in classification:
    print(f'{level}: allowed for documented workflow only')
# Out:
# public: allowed for documented workflow only
# internal: allowed for documented workflow only
# confidential: allowed for documented workflow only

# %% [markdown]
# ## 5B.4 Secure Orchestration Patterns
#
# Notebook anchor: `5b4-secure-orchestration-patterns`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.5 Security-Aware Planning
#
# Notebook anchor: `5b5-security-aware-planning`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.6 Secure Retrieval and Least Privilege
#
# Notebook anchor: `5b6-secure-retrieval-and-least-privilege`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
result = client.memories.search(
    query='fiber outage after upgrade',
    scope='organization',
    tags=['support', 'fiber'],
    limit=3,
    threshold=0.7,
    hybrid=True,
)
for item in result.items:
    print(item.id, item.scope, item.classification)
# Out:
# mem_001 organization internal
# mem_014 organization internal
# mem_022 organization internal

# %% [markdown]
# ## 5B.7 Policy Enforcement and Security Verifiers
#
# Notebook anchor: `5b7-policy-enforcement-and-security-verifiers`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.8 Safe Degradation and Incident Modes
#
# Notebook anchor: `5b8-safe-degradation-and-incident-modes`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.9 RLS as a Core Isolation Layer
#
# Notebook anchor: `5b9-rls-as-a-core-isolation-layer`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
print("current org:", 'org_support')
print("query status:", 'organization-scoped and RLS protected')
# Out:
# current org: org_support
# query status: organization-scoped and RLS protected

# %% [markdown]
# ## 5B.10 Security vs Latency Tradeoffs
#
# Notebook anchor: `5b10-security-vs-latency-tradeoffs`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.11 Security Failure Modes in Agentic Systems
#
# Notebook anchor: `5b11-security-failure-modes-in-agentic-systems`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.12 Human Approval and Access Governance
#
# Notebook anchor: `5b12-human-approval-and-access-governance`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
print('review queue item:', 'mem_022')
print('reason:', 'clearance required before promotion')
# Out:
# review queue item: mem_022
# reason: clearance required before promotion

# %% [markdown]
# ## 5B.13 Security Testing and Red Teaming
#
# Notebook anchor: `5b13-security-testing-and-red-teaming`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.14 Security Observability and Audit Signals
#
# Notebook anchor: `5b14-security-observability-and-audit-signals`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.15 When to Split Security Responsibilities
#
# Notebook anchor: `5b15-when-to-split-security-responsibilities`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.16 When to Merge Security Controls
#
# Notebook anchor: `5b16-when-to-merge-security-controls`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.17 Secure Delivery Workflow
#
# Notebook anchor: `5b17-secure-delivery-workflow`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18 End-to-End Secure Workflow Walkthrough
#
# Notebook anchor: `5b18-end-to-end-secure-workflow-walkthrough`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Example
#
# This example is designed to show a concrete goal, not just the API shape. The expected output demonstrates that the operation succeeded.

# %%
created = client.memories.create(
    title='Security escalation note',
    content='Tool attempted access outside approved scope.',
    scope='organization',
    classification='internal',
    tags=['security', 'audit'],
)
print(created.id, created.scope, created.classification)
# Out:
# mem_099 organization internal

# %% [markdown]
# ## 5B.18a Deep Dive: Preventing Cross-Tenant Data Leakage
#
# Notebook anchor: `5b18a-deep-dive-preventing-cross-tenant-data-leakage`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18b Existing Security Challenges in Agentic Architectures
#
# Notebook anchor: `5b18b-existing-security-challenges-in-agentic-architectures`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18c How Ninai Security Architecture Addresses Them
#
# Notebook anchor: `5b18c-how-ninai-security-architecture-addresses-them`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18d Security Challenge-to-Control Mapping
#
# Notebook anchor: `5b18d-security-challenge-to-control-mapping`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18e Designing for Security Stability
#
# Notebook anchor: `5b18e-designing-for-security-stability`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18f Security Operating Model
#
# Notebook anchor: `5b18f-security-operating-model`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18g RLS Anti-Patterns and How to Avoid Them
#
# Notebook anchor: `5b18g-rls-anti-patterns-and-how-to-avoid-them`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18h Secrets Management and Tool Credential Isolation
#
# Notebook anchor: `5b18h-secrets-management-and-tool-credential-isolation`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.18i Compliance Mapping: From Controls to Evidence
#
# Notebook anchor: `5b18i-compliance-mapping-from-controls-to-evidence`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.19 Security Postmortem: RLS Policy Drift
#
# Notebook anchor: `5b19-security-postmortem-rls-policy-drift`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.20 Chapter Lab
#
# Notebook anchor: `5b20-chapter-lab`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.

# %% [markdown]
# ## 5B.21 Conclusion
#
# Notebook anchor: `5b21-conclusion`
#
# This section mirrors the book subsection. Read the explanation, then run or inspect the example below to see the expected behavior in practice.

# %% [markdown]
# ### Practice note
#
# Use the nearest runnable example in this workbook as your starting point, then adapt the query, tags, scope, or review step to match this subsection.
